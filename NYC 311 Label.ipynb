# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn import decomposition

import warnings
warnings.filterwarnings("ignore") 

seed = 433

# %%
data = pd.read_csv('311_2019.csv', delimiter=',')
data = data.rename(columns={'Incident Zip': 'Zip', 'Complaint Type' : 'Complaint'})
data = data[['Zip', 'Complaint']]
data.Zip=pd.to_numeric(data.Zip,errors='coerce')
data=data.loc[(data.Zip>=10000)&(data.Zip<11500)]
data.head()
# Out:
#        Zip           Complaint
# 1  11434.0        Damaged Tree
# 2  11212.0            Graffiti
# 3  10016.0            Graffiti
# 4  10032.0            Graffiti
# 5  11420.0  Noise - Commercial

# %%
data = data.groupby(['Zip', 'Complaint']).size().reset_index(name='count')
data.head()
# Out:
#        Zip                  Complaint  count
# 0  10000.0          Abandoned Vehicle      1
# 1  10000.0           Animal in a Park      9
# 2  10000.0               Animal-Abuse      5
# 3  10000.0  Bike/Roller/Skate Chronic      4
# 4  10000.0         Consumer Complaint     23

# %%
#convert a list to a 2d table with zip codes as rows and complaint types as columns
data=pd.pivot_table(data,index='Zip',columns='Complaint',values='count',fill_value=0)
data.head()
# Out:
# Complaint  APPLIANCE  Abandoned Vehicle  Air Quality  Animal Abuse  \
# Zip
# 10000.0            0                  1            0             0
# 10001.0            0                  9           19             0
# 10002.0            0                 16            9             0
# 10003.0            1                 18            7             1
# 10004.0            0                  2            0             0
#
# Complaint  Animal Facility - No Permit  Animal in a Park  Animal-Abuse  \
# Zip
# 10000.0                              0                 9             5
# 10001.0                              0                 7            16
# 10002.0                              0                14            25
# 10003.0                              0                12            50
# 10004.0                              0                 1             1
#
# Complaint  Appliance  Asbestos  BEST/Site Safety  ...  Vacant Lot  Vending  \
# Zip                                               ...
# 10000.0            0         0                 0  ...           0        5
# 10001.0            0         1                 0  ...           0       64
# 10002.0            0         1                 0  ...           1       12
# 10003.0            0         8                 0  ...           0       29
# 10004.0            0         0                 0  ...           0      149
#
# Complaint  Violation of Park Rules  WATER LEAK  Water Conservation  \
# Zip
# 10000.0                         25           0                   0
# 10001.0                          8           0                   2
# 10002.0                         54           0                   0
# 10003.0                         43           0                   1
# 10004.0                         25           0                   0
#
# Complaint  Water Leak  Water Quality  Water System  Window Guard  \
# Zip
# 10000.0             0              0             0             0
# 10001.0             0              2            23             0
# 10002.0             0              6            26             0
# 10003.0             0             17            25             0
# 10004.0             0              0             1             0
#
# Complaint  X-Ray Machine/Equipment
# Zip
# 10000.0                          0
# 10001.0                          0
# 10002.0                          0
# 10003.0                          0
# 10004.0                          0
#
# [5 rows x 199 columns]

# %%
Total=data.sum(axis=1) #total 311 activity per zip code
data=data.div(data.sum(axis=1), axis=0) #normalize activity of various cathegories within zip code by total
data=data.loc[Total>100] #keep only those zip codes having sufficient activity
data.head()
# Out:
# Complaint  APPLIANCE  Abandoned Vehicle  Air Quality  Animal Abuse  \
# Zip
# 10000.0     0.000000           0.005464     0.000000      0.000000
# 10001.0     0.000000           0.001866     0.003939      0.000000
# 10002.0     0.000000           0.002056     0.001157      0.000000
# 10003.0     0.000135           0.002431     0.000946      0.000135
# 10004.0     0.000000           0.001427     0.000000      0.000000
#
# Complaint  Animal Facility - No Permit  Animal in a Park  Animal-Abuse  \
# Zip
# 10000.0                            0.0          0.049180      0.027322
# 10001.0                            0.0          0.001451      0.003317
# 10002.0                            0.0          0.001799      0.003213
# 10003.0                            0.0          0.001621      0.006754
# 10004.0                            0.0          0.000713      0.000713
#
# Complaint  Appliance  Asbestos  BEST/Site Safety  ...  Vacant Lot   Vending  \
# Zip                                               ...
# 10000.0          0.0  0.000000               0.0  ...    0.000000  0.027322
# 10001.0          0.0  0.000207               0.0  ...    0.000000  0.013270
# 10002.0          0.0  0.000129               0.0  ...    0.000129  0.001542
# 10003.0          0.0  0.001081               0.0  ...    0.000000  0.003917
# 10004.0          0.0  0.000000               0.0  ...    0.000000  0.106277
#
# Complaint  Violation of Park Rules  WATER LEAK  Water Conservation  \
# Zip
# 10000.0                   0.136612         0.0            0.000000
# 10001.0                   0.001659         0.0            0.000415
# 10002.0                   0.006940         0.0            0.000000
# 10003.0                   0.005808         0.0            0.000135
# 10004.0                   0.017832         0.0            0.000000
#
# Complaint  Water Leak  Water Quality  Water System  Window Guard  \
# Zip
# 10000.0           0.0       0.000000      0.000000           0.0
# 10001.0           0.0       0.000415      0.004769           0.0
# 10002.0           0.0       0.000771      0.003341           0.0
# 10003.0           0.0       0.002296      0.003377           0.0
# 10004.0           0.0       0.000000      0.000713           0.0
#
# Complaint  X-Ray Machine/Equipment
# Zip
# 10000.0                        0.0
# 10001.0                        0.0
# 10002.0                        0.0
# 10003.0                        0.0
# 10004.0                        0.0
#
# [5 rows x 199 columns]

# %%
# Add the income level feature into the dataset

income = pd.read_csv('data/zipcode_income.csv', delimiter=',')
income = income.iloc[:,:2]
income[income.isna()] = 0
income.rename(columns={'ZIPCODE':'Zip', 'median_familyIncome(USD)' : 'income'}, inplace=True)
income=income.loc[(income.Zip>=10000)&(income.Zip<11500)]
income['income'][income['income'] == 0.0] = income['income'].mean() # Replace 0 income with mean
income['income'] = income['income'] / income['income'].sum()
income.head()
# Out:
#      Zip    income
# 1  10001  0.007785
# 2  10002  0.002521
# 3  10003  0.011663
# 4  10004  0.005682
# 5  10006  0.012767

# %%
# Add the area size feature into the dataset

area = pd.read_csv('data/zips_area.csv', delimiter=',')
area = area.iloc[:,:2]
area.rename(columns={'ZIPCODE':'Zip', 'AREA' : 'area'}, inplace=True)
areas = area.copy()
area=area.loc[(area.Zip>=10000)&(area.Zip<11500)]
area['area'] = area['area'] / area['area'].sum()
area.head()
# Out:
#      Zip      area
# 0  11436  0.002820
# 1  11213  0.003681
# 2  11212  0.005214
# 3  11225  0.002944
# 4  11218  0.004580

# %%
# Add the population jobs feature into the dataset

jobs = pd.read_csv('data/zipcode_population_Jobs.csv', delimiter=',')
jobs = jobs.iloc[:,:2]
jobs.rename(columns={'ZIPCODE':'Zip', 'totalJobs' : 'jobs'}, inplace=True)
jobs['jobs'] = jobs['jobs'] / areas['area']
jobs.head()
# Out:
#      Zip      jobs
# 0  10001  0.009204
# 1  10002  0.000904
# 2  10003  0.002335
# 3  10004  0.003356
# 4  10005  0.001389

# %%
# Add the population feature into the dataset

population = pd.read_csv('data/zipcode_population_Jobs.csv', delimiter=',')
population = population[['ZIPCODE','POPULATION']]
population.rename(columns={'ZIPCODE':'Zip', 'POPULATION' : 'population'}, inplace=True)
population['population'][population['population'] < 30.0] = population['population'].mean() # Replace 0 population with mean
population['population'] = population['population'] / areas['area']
population.head()
# Out:
#      Zip  population
# 0  10001    0.000987
# 1  10002    0.002744
# 2  10003    0.001331
# 3  10004    0.000092
# 4  10005    0.000220

# %%
# Add the house price feature into the dataset

housePrice = pd.read_csv('data/zipcode_housePrice.csv', delimiter=',')
weights = [5000,12500,17500,22500,27500,32500,37500,45000,55000,65000,75000,85000
                    ,95000,112500,137500,162500,187500,225000,275000,350000,450000,625000,875000
                        ,1250000,1750000,2000000]
for i in range(len(weights)):
    housePrice.iloc[i,2:] = housePrice.iloc[i,2:]*weights[i]
housePrice.iloc[:,1] [housePrice.iloc[:,1] == 0] = 1

tmp = (housePrice.iloc[:,2:] != 0 ).sum(axis=1)
tmp[tmp == 0] = 1
housePrice = pd.concat([housePrice.iloc[:,0],housePrice.iloc[:,2:].sum(axis=1) / tmp ], axis = 1 )
housePrice.rename(columns={'ZIPCODE':'Zip', 0: 'house_price'}, inplace=True)
housePrice['house_price'] = housePrice['house_price']/housePrice['house_price'].sum()

# %%
data = pd.merge(data, income, on="Zip")
data = data.merge(population)
data = data.merge(jobs)
data = data.merge(housePrice)
data = data.merge(area)
data = data.drop_duplicates(subset=['Zip'], keep='last')
data.head()
# Out:
#        Zip  APPLIANCE  Abandoned Vehicle  Air Quality  Animal Abuse  \
# 0  10001.0   0.000000           0.001866     0.003939      0.000000
# 1  10002.0   0.000000           0.002056     0.001157      0.000000
# 2  10003.0   0.000135           0.002431     0.000946      0.000135
# 6  10004.0   0.000000           0.001427     0.000000      0.000000
# 7  10006.0   0.000000           0.007491     0.001873      0.000000
#
#    Animal Facility - No Permit  Animal in a Park  Animal-Abuse  Appliance  \
# 0                          0.0          0.001451      0.003317        0.0
# 1                          0.0          0.001799      0.003213        0.0
# 2                          0.0          0.001621      0.006754        0.0
# 6                          0.0          0.000713      0.000713        0.0
# 7                          0.0          0.000000      0.000000        0.0
#
#    Asbestos  ...  Water Leak  Water Quality  Water System  Window Guard  \
# 0  0.000207  ...         0.0       0.000415      0.004769           0.0
# 1  0.000129  ...         0.0       0.000771      0.003341           0.0
# 2  0.001081  ...         0.0       0.002296      0.003377           0.0
# 6  0.000000  ...         0.0       0.000000      0.000713           0.0
# 7  0.000000  ...         0.0       0.000000      0.001873           0.0
#
#    X-Ray Machine/Equipment    income  population      jobs  house_price  \
# 0                      0.0  0.007785    0.000987  0.009204     0.000437
# 1                      0.0  0.002521    0.002744  0.000904     0.000571
# 2                      0.0  0.011663    0.001331  0.002335     0.002566
# 6                      0.0  0.005682    0.000092  0.003356     0.000000
# 7                      0.0  0.012767    0.000076  0.000546     0.001680
#
#        area
# 0  0.002211
# 1  0.003265
# 2  0.001930
# 6  0.000083
# 7  0.000213
#
# [5 rows x 205 columns]

# %%
data1 = pd.read_csv('data/zips_merged.csv', delimiter=',')
data1 = data1.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
data1 = data1[data1.destination.isin(data1.origin.unique())]
data1 = data1[['origin', 'destination', 'weight', 'true_label']]
data1 = data1[data1['origin'].isin(data['Zip'])][data1['destination'].isin(data['Zip'])]

# %%
data2 = data1[['origin','true_label']].drop_duplicates()
data2 = data2.rename(columns={'origin': 'Zip'})
data = data.merge(data2)

# %%
data
# Out:
#          Zip  APPLIANCE  Abandoned Vehicle  Air Quality  Animal Abuse  \
# 0    10001.0   0.000000           0.001866     0.003939      0.000000
# 1    10002.0   0.000000           0.002056     0.001157      0.000000
# 2    10003.0   0.000135           0.002431     0.000946      0.000135
# 3    10004.0   0.000000           0.001427     0.000000      0.000000
# 4    10006.0   0.000000           0.007491     0.001873      0.000000
# ..       ...        ...                ...          ...           ...
# 163  11432.0   0.000202           0.014747     0.000000      0.000000
# 164  11433.0   0.000000           0.075949     0.000844      0.000000
# 165  11434.0   0.000000           0.097811     0.000581      0.000000
# 166  11435.0   0.000000           0.046316     0.000632      0.000000
# 167  11436.0   0.000000           0.078557     0.000802      0.000000
#
#      Animal Facility - No Permit  Animal in a Park  Animal-Abuse  Appliance  \
# 0                            0.0          0.001451      0.003317        0.0
# 1                            0.0          0.001799      0.003213        0.0
# 2                            0.0          0.001621      0.006754        0.0
# 3                            0.0          0.000713      0.000713        0.0
# 4                            0.0          0.000000      0.000000        0.0
# ..                           ...               ...           ...        ...
# 163                          0.0          0.001414      0.003434        0.0
# 164                          0.0          0.000844      0.006751        0.0
# 165                          0.0          0.002324      0.010459        0.0
# 166                          0.0          0.000211      0.005474        0.0
# 167                          0.0          0.000000      0.004810        0.0
#
#      Asbestos  ...  Water Quality  Water System  Window Guard  \
# 0    0.000207  ...       0.000415      0.004769           0.0
# 1    0.000129  ...       0.000771      0.003341           0.0
# 2    0.001081  ...       0.002296      0.003377           0.0
# 3    0.000000  ...       0.000000      0.000713           0.0
# 4    0.000000  ...       0.000000      0.001873           0.0
# ..        ...  ...            ...           ...           ...
# 163  0.001212  ...       0.000404      0.009697           0.0
# 164  0.000844  ...       0.000281      0.009001           0.0
# 165  0.000387  ...       0.000000      0.012396           0.0
# 166  0.000421  ...       0.000211      0.004842           0.0
# 167  0.000401  ...       0.000401      0.009218           0.0
#
#      X-Ray Machine/Equipment    income  population      jobs   house_price  \
# 0                        0.0  0.007785    0.000987  0.009204  4.365055e-04
# 1                        0.0  0.002521    0.002744  0.000904  5.714253e-04
# 2                        0.0  0.011663    0.001331  0.002335  2.566312e-03
# 3                        0.0  0.005682    0.000092  0.003356  0.000000e+00
# 4                        0.0  0.012767    0.000076  0.000546  1.680263e-03
# ..                       ...       ...         ...       ...           ...
# 163                      0.0  0.004611    0.026166  0.008975  8.367300e-08
# 164                      0.0  0.004186    0.035234  0.005823  4.455757e-08
# 165                      0.0  0.005187    0.037105  0.009785  8.299273e-08
# 166                      0.0  0.004516    0.001320  0.000202  4.648500e-08
# 167                      0.0  0.005008    0.000438  0.000031  2.367334e-08
#
#          area  true_label
# 0    0.002211           1
# 1    0.003265           1
# 2    0.001930           1
# 3    0.000083           1
# 4    0.000213           1
# ..        ...         ...
# 163  0.007476           4
# 164  0.005930           4
# 165  0.010855           4
# 166  0.005231           4
# 167  0.002820           4
#
# [168 rows x 206 columns]

# %%
# function for loading data, returns adjacency matrix, initial feature assignments and true labels

def load_data():

    G = nx.from_pandas_edgelist(data1, 'origin', 'destination', 'weight',create_using=nx.DiGraph())
    adj_list = np.array([nx.adjacency_matrix(G).todense()], dtype=float)
    
    init_feat = data.to_numpy()[:,:-6]
    
    true_label = data.to_numpy()[:,-1].reshape(-1, 1)
    
    return adj_list,init_feat,true_label

adj,feature,labels = load_data()

pca = decomposition.PCA(n_components=10)
feature = pca.fit_transform(feature)

features = np.expand_dims(feature, axis=0)

# %%
# import packages

import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
torch.set_printoptions(sci_mode=False)
import time

# %%
# set initial model config

cuda = torch.cuda.is_available()
weight_decay = 1e-8
epochs = 2000
seed = 635
hidden = 16
lr = 0.0001

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %%
def normalize(adj):

    adj = torch.FloatTensor(adj)
    adj_id = torch.FloatTensor(torch.eye(adj.shape[1]))
    adj_id = adj_id.reshape((1, adj.shape[1], adj.shape[1]))
    adj_id = adj_id.repeat(adj.shape[0], 1, 1)
    adj = adj + adj_id
    rowsum = torch.FloatTensor(adj.sum(2))
    degree_mat_inv_sqrt = torch.diag_embed(torch.float_power(rowsum,-0.5), dim1=-2, dim2=-1).float()
    adj_norm = torch.bmm(torch.transpose(torch.bmm(adj,degree_mat_inv_sqrt),1,2),degree_mat_inv_sqrt)

    return adj_norm

# %%
def doublerelu(x):
    return torch.clamp(x, 0, 1)

# %%
class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features, first):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        
        # Initialse W1 = 1, W2 = 0 as pytorch learnable weights (parameters) that have require_grad = True which is
        # required for calculating gradients while backpropogating using gradient descent
        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        if not first:
            self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))
        else:
            self.weight2 = Parameter(torch.empty(batch_size, in_features, out_features))
            nn.init.kaiming_normal_(self.weight2, mode='fan_out')

    def forward(self, input, adj):
        # first term H*W1
        v1 = torch.bmm(input, self.weight1)
        # second term adj_norm*H*W2
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        # adding the two terms
        output = v1 + v2

        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden, first):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, nfeat, hidden, first)
        self.gc2 = GNN1Layer(batch_size, hidden, ndim, first)

    def forward(self, x, adj):

        # Applying activation function sigma (doublerelu) on the layer propogation
        x = doublerelu(self.gc1(x, adj))
        x = doublerelu(self.gc2(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        
        return x

# %%
def train(adj,features,labels,train_indices,val_indices,first=False):
    
    # calculate symmetric normalisation for layer propogation
    adj_norm = normalize(adj)
    
    labels = labels - 1
    
    # Convert from numpy to torch tensors
    adj = torch.FloatTensor(adj)
    adj_norm = torch.FloatTensor(adj_norm)
    features = torch.FloatTensor(features)
    labels = torch.FloatTensor(labels)
    
    # initialise the model
    model = GNN1(batch_size=adj.shape[0],
                nfeat=features.shape[-1],
                ndim=5,
                hidden=hidden,
                first=first)
    
    # Transfer the weights to GPU for training
    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        labels = labels.cuda()
    
    # Train model
    t_total = time.time()

    # Using adam optimizers for backpropogation
    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    # loss function criteria is cross entropy loss
    criterion = nn.CrossEntropyLoss()
    
    # Train for the no of epochs
    for epoch in range(epochs):

        t = time.time()
        
        model.train()
        
        # Pytorch accumulates gradient after every operation on tensors (defined by the model architecture)
        # with require_grad = True. With each new epoch, we need to reset this gradient to 0 to calculate gradient
        # for this epoch.
        optimizer.zero_grad()

        # get the output from forward propogation of our model
        output = model(features, adj_norm)
        
        
        # Calculate Train accuracy
        train_output = output[:,train_indices,:]
        train_labels = labels[train_indices,:]
        
        train_accuracy = torch.sum(torch.argmax(train_output,axis=2)==train_labels.reshape(1,-1))/train_labels.shape[0]
        
        # Calculate the loss between our models training output and true label
        loss = criterion(output[0],labels.reshape(-1).long())
        
        # Calculate the gradients 
        loss.backward(retain_graph=True)

        # Update the weights
        optimizer.step()
        
        model.eval()
        
        # Calculate Validation accuracy
        with torch.no_grad():
            val_output = output[:,val_indices,:]
            val_labels = labels[val_indices,:]
            val_accuracy = torch.sum(torch.argmax(val_output,axis=2)==val_labels.reshape(1,-1))/val_labels.shape[0]

        # Print summary of training 
        if epoch == 0:
            best_loss = loss
            best_output = output
            best_acc = train_accuracy
            best_val_acc = val_accuracy
            best_val_output = val_output
        else:
            if loss < best_loss:
                best_loss = loss
                best_output = output
                best_acc = train_accuracy
                best_val_acc = val_accuracy
                best_val_output = val_output

        if epoch == 0 or (epoch+1) % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Train Accuracy: {:.4f}'.format(best_acc.item()),
                  'Validation Accuracy: {:.4f}'.format(best_val_acc.item()),
                  'Loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return best_loss,best_output#,best_val_output

# %%
# set Train %

train_percentage = .8
    
# Train set
number_of_rows = features[0].shape[0]
train_indices = np.random.choice(number_of_rows, size=int(train_percentage*number_of_rows), replace=False)
val_indices = np.setdiff1d(np.arange(adj.shape[1]),train_indices)

# Start Train
prev_loss, op = train(adj,features,labels,train_indices,val_indices,True)

# Keep training recurrently until the loss stops decreasing
loss, op = train(adj,op.cpu().detach().numpy(),labels,train_indices,val_indices)
while loss < prev_loss :
    prev_loss = loss
    loss, op = train(adj,op.cpu().detach().numpy(),labels,train_indices,val_indices)
# Out:
# Epoch: 0001 Train Accuracy: 0.0672 Validation Accuracy: 0.0588 Loss: 1.65107405 time: 1.3163s
# Epoch: 1000 Train Accuracy: 0.5522 Validation Accuracy: 0.4118 Loss: 1.43231416 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.5522 Validation Accuracy: 0.4118 Loss: 1.43231416 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 5.5343s
# Epoch: 0001 Train Accuracy: 0.5522 Validation Accuracy: 0.4118 Loss: 1.43231416 time: 0.0020s
# Epoch: 1000 Train Accuracy: 0.5970 Validation Accuracy: 0.4412 Loss: 1.30339682 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.6269 Validation Accuracy: 0.4706 Loss: 1.28486216 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.4128s
# Epoch: 0001 Train Accuracy: 0.6269 Validation Accuracy: 0.4706 Loss: 1.28486216 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.6716 Validation Accuracy: 0.7059 Loss: 1.21668589 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.6791 Validation Accuracy: 0.7353 Loss: 1.19057739 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.5605s
# Epoch: 0001 Train Accuracy: 0.6791 Validation Accuracy: 0.7353 Loss: 1.19057739 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.7164 Validation Accuracy: 0.7353 Loss: 1.17322516 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.7388 Validation Accuracy: 0.7647 Loss: 1.15232670 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.6751s
# Epoch: 0001 Train Accuracy: 0.7388 Validation Accuracy: 0.7647 Loss: 1.15232670 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.7612 Validation Accuracy: 0.7647 Loss: 1.14342546 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.7537 Validation Accuracy: 0.7647 Loss: 1.13181937 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.7362s
# Epoch: 0001 Train Accuracy: 0.7537 Validation Accuracy: 0.7647 Loss: 1.13181937 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.7761 Validation Accuracy: 0.7647 Loss: 1.12605798 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.7537 Validation Accuracy: 0.7941 Loss: 1.11957657 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.8285s
# Epoch: 0001 Train Accuracy: 0.7537 Validation Accuracy: 0.7941 Loss: 1.11957657 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.7687 Validation Accuracy: 0.7941 Loss: 1.11550868 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.7910 Validation Accuracy: 0.8235 Loss: 1.10912108 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.8530s
# Epoch: 0001 Train Accuracy: 0.7910 Validation Accuracy: 0.8235 Loss: 1.10912108 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.7910 Validation Accuracy: 0.8235 Loss: 1.10427725 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.7985 Validation Accuracy: 0.7941 Loss: 1.09862459 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.7821s
# Epoch: 0001 Train Accuracy: 0.7985 Validation Accuracy: 0.7941 Loss: 1.09862459 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8134 Validation Accuracy: 0.7941 Loss: 1.09442389 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.8134 Validation Accuracy: 0.8529 Loss: 1.08349895 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.8098s
# Epoch: 0001 Train Accuracy: 0.8134 Validation Accuracy: 0.8529 Loss: 1.08349895 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8209 Validation Accuracy: 0.8235 Loss: 1.07549584 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.8284 Validation Accuracy: 0.8529 Loss: 1.06564152 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.5686s
# Epoch: 0001 Train Accuracy: 0.8284 Validation Accuracy: 0.8529 Loss: 1.06564152 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8358 Validation Accuracy: 0.8529 Loss: 1.05989099 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8433 Validation Accuracy: 0.8824 Loss: 1.04897022 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.6984s
# Epoch: 0001 Train Accuracy: 0.8433 Validation Accuracy: 0.8824 Loss: 1.04897022 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8582 Validation Accuracy: 0.8824 Loss: 1.04489267 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8507 Validation Accuracy: 0.9118 Loss: 1.03815866 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.3031s
# Epoch: 0001 Train Accuracy: 0.8507 Validation Accuracy: 0.9118 Loss: 1.03815866 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8433 Validation Accuracy: 0.9118 Loss: 1.03446102 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8731 Validation Accuracy: 0.9118 Loss: 1.02894831 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.9467s
# Epoch: 0001 Train Accuracy: 0.8731 Validation Accuracy: 0.9118 Loss: 1.02894831 time: 0.0020s
# Epoch: 1000 Train Accuracy: 0.8731 Validation Accuracy: 0.9118 Loss: 1.02573228 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8731 Validation Accuracy: 0.9118 Loss: 1.02016544 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.7700s
# Epoch: 0001 Train Accuracy: 0.8731 Validation Accuracy: 0.9118 Loss: 1.02016544 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01883733 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01819026 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.7447s
# Epoch: 0001 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01819026 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01781297 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01718163 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.6847s
# Epoch: 0001 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01718163 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01682198 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01618564 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.3616s
# Epoch: 0001 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01618564 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01550508 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01430738 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.0403s
# Epoch: 0001 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01430738 time: 0.0020s
# Epoch: 1000 Train Accuracy: 0.8806 Validation Accuracy: 0.9118 Loss: 1.01373017 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8881 Validation Accuracy: 0.9118 Loss: 1.01282060 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.7466s
# Epoch: 0001 Train Accuracy: 0.8881 Validation Accuracy: 0.9118 Loss: 1.01282060 time: 0.0040s
# Epoch: 1000 Train Accuracy: 0.8955 Validation Accuracy: 0.9118 Loss: 1.01182127 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8955 Validation Accuracy: 0.9118 Loss: 1.00957000 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.6839s
# Epoch: 0001 Train Accuracy: 0.8955 Validation Accuracy: 0.9118 Loss: 1.00957000 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8955 Validation Accuracy: 0.9118 Loss: 1.00866377 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00768912 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.7007s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00768912 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00750482 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00733876 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.1070s
# Epoch: 0001 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00733876 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00726259 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00706494 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.2508s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00706494 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00689065 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00648475 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 4.7456s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00648475 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00627041 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00616097 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.8152s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00616097 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00611997 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00605869 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.9572s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00605869 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00602877 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00595450 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.3990s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00595450 time: 0.0040s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00587463 time: 0.0022s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00560713 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.1933s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00560713 time: 0.0020s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00539947 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00503540 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.4319s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00503540 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00469792 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00423372 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 5.1375s
# Epoch: 0001 Train Accuracy: 0.8955 Validation Accuracy: 0.8824 Loss: 1.00423372 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00379586 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00316131 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 5.1077s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00316131 time: 0.0020s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.8824 Loss: 1.00252903 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 1.00149834 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 5.2336s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 1.00149834 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 1.00061750 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 0.99920928 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 5.6395s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 0.99920928 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 0.99788946 time: 0.0040s
# Epoch: 2000 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 0.99507368 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.1890s
# Epoch: 0001 Train Accuracy: 0.9030 Validation Accuracy: 0.9118 Loss: 0.99507368 time: 0.0040s
# Epoch: 1000 Train Accuracy: 0.9104 Validation Accuracy: 0.9118 Loss: 0.99251783 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9104 Validation Accuracy: 0.9118 Loss: 0.98911113 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.1098s
# Epoch: 0001 Train Accuracy: 0.9104 Validation Accuracy: 0.9118 Loss: 0.98911113 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9179 Validation Accuracy: 0.9118 Loss: 0.98752803 time: 0.0020s
# Epoch: 2000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98476392 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.0660s
# Epoch: 0001 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98476392 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98247004 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98184139 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 5.2367s
# Epoch: 0001 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98184139 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98182923 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98182869 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 5.4626s
# Epoch: 0001 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98182869 time: 0.0030s
# Epoch: 1000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98182869 time: 0.0030s
# Epoch: 2000 Train Accuracy: 0.9254 Validation Accuracy: 0.9118 Loss: 0.98182869 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 4.9802s
